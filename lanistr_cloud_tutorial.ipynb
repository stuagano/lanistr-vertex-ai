# %% [markdown]
# # LANISTR Cloud Deployment Tutorial
#
# This notebook shows you how to deploy LANISTR training jobs to Google Cloud Vertex AI using the actual project configurations.
#
# ## What is LANISTR?
#
# LANISTR (LANguage, Image, and STRuctured data) is a multimodal learning framework that can handle:
#
# - **Unstructured Data**: Text (reports, descriptions) and Images (X-rays, product photos)
# - **Structured Data**: Tabular data (patient demographics, product features) and Time-series data (vital signs, sensor readings)
#
# ### Key Features:
#
# 1. **Masking-based Training**: Uses masking strategies across both unimodal and multimodal levels
# 2. **Cross-modal Learning**: Introduces similarity-based multimodal masking loss for learning cross-modal relations
# 3. **Missing Modality Robustness**: Works effectively even when some modalities are missing from samples
# 4. **Cloud-Native**: Designed for deployment on Google Cloud Vertex AI
#
# ### Supported Datasets:
#
# - **MIMIC-IV**: Healthcare dataset with chest X-rays, clinical notes, and patient vitals
# - **Amazon Product Review**: Retail dataset with product images, reviews, and metadata
#
# ## Why Cloud Deployment?
#
# 1. **No Local GPU Required**: Training happens on Google Cloud's powerful GPU instances
# 2. **Scalability**: Easy to scale from single GPU to multi-GPU or distributed training
# 3. **Cost Effective**: Pay only for compute time used
# 4. **Reproducible**: Consistent environment across different machines
# 5. **Managed Infrastructure**: No need to manage CUDA, drivers, or hardware
#
# Let's get started with cloud deployment!

# %% [markdown]
# ## Prerequisites Setup
#
# First, let's set up the minimal local environment needed for cloud submission.

# %%
# Import necessary libraries for cloud deployment
import os
import sys
import json
import yaml
from pathlib import Path
from datetime import datetime

# Add the lanistr directory to the path
sys.path.append('./lanistr')

# Check if we're in the right directory
print(f"Current working directory: {os.getcwd()}")
print(f"LANISTR directory exists: {os.path.exists('./lanistr')}")

# Check if we have the cloud requirements installed
try:
    import omegaconf
    print("✅ Core utilities imported successfully")
except ImportError as e:
    print(f"❌ Missing core utilities: {e}")
    print("Run: pip install -r requirements-cloud.txt")

# Check Google Cloud setup
try:
    from google.cloud import aiplatform
    from google.cloud import storage
    print("✅ Google Cloud libraries imported successfully")
except ImportError as e:
    print(f"❌ Missing Google Cloud libraries: {e}")
    print("Run: pip install -r requirements-cloud.txt")
# Out:
# Current working directory: /Users/stuartgano/lanistr
# LANISTR directory exists: True
# ✅ Core utilities imported successfully
# ✅ Google Cloud libraries imported successfully

# %% [markdown]
# ## Google Cloud Setup
#
# Before we can submit jobs to Vertex AI, we need to set up Google Cloud authentication and configuration.

# %%
# Google Cloud configuration - UPDATE THESE WITH YOUR ACTUAL VALUES
PROJECT_ID = "mgm-digitalconcierge"  # Replace with your actual project ID
REGION = "us-central1"  # Choose your preferred region
BUCKET_NAME = "lanistr-mgm-digitalconcierge-data"  # Replace with your bucket name

# Initialize Vertex AI
try:
    aiplatform.init(project=PROJECT_ID, location=REGION)
    print(f"✅ Vertex AI initialized for project: {PROJECT_ID}")
    print(f"✅ Region: {REGION}")
except Exception as e:
    print(f"❌ Failed to initialize Vertex AI: {e}")
    print("\nTo set up Google Cloud:")
    print("1. Install Google Cloud SDK: https://cloud.google.com/sdk/docs/install")
    print("2. Run: gcloud auth login")
    print("3. Run: gcloud config set project YOUR_PROJECT_ID")
    print("4. Enable Vertex AI API: gcloud services enable aiplatform.googleapis.com")

# Test bucket access
try:
    storage_client = storage.Client(project=PROJECT_ID)
    bucket = storage_client.bucket(BUCKET_NAME)
    print(f"✅ Successfully connected to bucket: {BUCKET_NAME}")
except Exception as e:
    print(f"❌ Failed to access bucket: {e}")
    print("\nTo create a bucket:")
    print(f"gcloud storage buckets create gs://{BUCKET_NAME} --location={REGION}")
# Out:
# ✅ Vertex AI initialized for project: mgm-digitalconcierge
# ✅ Region: us-central1
# ✅ Successfully connected to bucket: lanistr-mgm-digitalconcierge-data

# %% [markdown]
# ## Understanding LANISTR Project Structure
#
# Let's examine the actual project structure and configurations.

# %%
# List available configurations
print("Available Vertex AI configurations:")
vertex_configs = [
    'vertex_ai_configs/mimic_pretrain_vertex.yaml',
    'vertex_ai_configs/mimic_finetune_vertex.yaml',
    'vertex_ai_configs/amazon_pretrain_vertex.yaml'
]
for config in vertex_configs:
    if os.path.exists(config):
        print(f"  ✅ {config}")
    else:
        print(f"  ❌ {config} (not found)")

print("\nAvailable LANISTR configurations:")
lanistr_configs = [
    'lanistr/configs/mimic_pretrain.yaml',
    'lanistr/configs/mimic_finetune.yaml',
    'lanistr/configs/amazon_finetune_beauty.yaml',
    'lanistr/configs/amazon_finetune_fashion.yaml',
    'lanistr/configs/amazon_pretrain_office.yaml'
]
for config in lanistr_configs:
    if os.path.exists(config):
        print(f"  ✅ {config}")
    else:
        print(f"  ❌ {config} (not found)")

# Load and display a sample configuration
sample_config_path = 'lanistr/configs/mimic_pretrain.yaml'
if os.path.exists(sample_config_path):
    with open(sample_config_path, 'r') as f:
        config = yaml.safe_load(f)
    
    print("\nSample Configuration Structure:")
    print(f"Dataset: {config.get('dataset_name', 'N/A')}")
    print(f"Task: {config.get('task', 'N/A')}")
    print(f"Modalities enabled:")
    print(f"  - Image: {config.get('image', False)}")
    print(f"  - Text: {config.get('text', False)}")
    print(f"  - Tabular: {config.get('tab', False)}")
    print(f"  - Time-series: {config.get('time', False)}")
    print(f"\nTraining parameters:")
    print(f"  - Batch size: {config.get('train_batch_size', 'N/A')}")
    print(f"  - Learning rate: {config.get('optimizer', {}).get('learning_rate', 'N/A')}")
    print(f"  - Epochs: {config.get('scheduler', {}).get('num_epochs', 'N/A')}")
    print(f"\nData paths:")
    print(f"  - Root data: {config.get('root_data_dir', 'N/A')}")
    print(f"  - Output: {config.get('output_dir', 'N/A')}")

# %% [markdown]
# ## Data Preparation for Cloud
#
# Let's prepare and upload the actual data from your project to Google Cloud Storage.

# %%
# Data preparation functions
def upload_data_to_gcs(local_path, gcs_path):
    """Upload data to Google Cloud Storage"""
    try:
        storage_client = storage.Client(project=PROJECT_ID)
        bucket = storage_client.bucket(BUCKET_NAME)
        
        if os.path.isfile(local_path):
            # Upload single file
            blob = bucket.blob(gcs_path)
            blob.upload_from_filename(local_path)
            print(f"✅ Uploaded {local_path} to gs://{BUCKET_NAME}/{gcs_path}")
        elif os.path.isdir(local_path):
            # Upload directory recursively
            for root, dirs, files in os.walk(local_path):
                for file in files:
                    local_file_path = os.path.join(root, file)
                    relative_path = os.path.relpath(local_file_path, local_path)
                    gcs_file_path = os.path.join(gcs_path, relative_path)
                    
                    blob = bucket.blob(gcs_file_path)
                    blob.upload_from_filename(local_file_path)
                    print(f"✅ Uploaded {local_file_path} to gs://{BUCKET_NAME}/{gcs_file_path}")
        
        return f"gs://{BUCKET_NAME}/{gcs_path}"
    except Exception as e:
        print(f"❌ Failed to upload {local_path}: {e}")
        return None

# Actual data paths from your project
print("Actual Data Paths in Your Project:")
data_paths = [
    ('./data/mimic-iv/', 'lanistr-data/mimic-iv/'),
    ('./lanistr/configs/', 'lanistr-configs/'),
    ('./vertex_ai_configs/', 'vertex-ai-configs/')
]

for local_path, gcs_path in data_paths:
    if os.path.exists(local_path):
        print(f"✅ {local_path} -> gs://{BUCKET_NAME}/{gcs_path}")
    else:
        print(f"❌ {local_path} (not found)")

# Example: Upload MIMIC-IV data
print("\nTo upload MIMIC-IV data:")
print("upload_data_to_gcs('./data/mimic-iv/', 'lanistr-data/mimic-iv/')")
print("\nTo upload configurations:")
print("upload_data_to_gcs('./lanistr/configs/', 'lanistr-configs/')")
print("upload_data_to_gcs('./vertex_ai_configs/', 'vertex-ai-configs/')")
# Out:
# Actual Data Paths in Your Project:
# ✅ ./data/mimic-iv/ -> gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/
# ✅ ./lanistr/configs/ -> gs://lanistr-mgm-digitalconcierge-data/lanistr-configs/
# ✅ ./vertex_ai_configs/ -> gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/
#
# To upload MIMIC-IV data:
# upload_data_to_gcs('./data/mimic-iv/', 'lanistr-data/mimic-iv/')
#
# To upload configurations:
# upload_data_to_gcs('./lanistr/configs/', 'lanistr-configs/')
# upload_data_to_gcs('./vertex_ai_configs/', 'vertex-ai-configs/')

# %% [markdown]
# ## Building the Container with Cloud Build
#
# Instead of building the container locally, we'll use Google Cloud Build which is faster and more reliable.
#
# ### Option 1: Use the Automated Script (Recommended)
#
# We've created an automated script that handles everything:
#
# 1. **Update the script**: Edit `trigger_cloud_build.sh` and set your PROJECT_ID
# 2. **Run the script**: `./trigger_cloud_build.sh`
#
# The script will:
# - ✅ Check prerequisites (gcloud, authentication)
# - ✅ Enable required APIs
# - ✅ Trigger Cloud Build
# - ✅ Stream build logs to your terminal
# - ✅ Provide build status and container URI
#
# ### Option 2: Manual Cloud Build
#
# If you prefer manual control:
#
# ```bash
# # 1. Enable required APIs
# gcloud services enable cloudbuild.googleapis.com
# gcloud services enable containerregistry.googleapis.com
# gcloud services enable aiplatform.googleapis.com
#
# # 2. Trigger Cloud Build
# gcloud builds submit --config=cloudbuild.yaml .
#
# # 3. Monitor build progress
# gcloud builds list --limit=5
# ```
#
# ### Why Cloud Build?
#
# - **No Local Resources**: Builds happen on Google Cloud's powerful infrastructure
# - **Faster Builds**: High-CPU machines with more memory and disk space
# - **Consistent Environment**: Same build environment every time
# - **No Docker Installation**: No need to install Docker locally
# - **Automatic Pushing**: Container is automatically pushed to Container Registry
#
# ### Container Details
#
# - **Base Image**: NVIDIA CUDA 11.3 with cuDNN8 on Ubuntu 20.04
# - **Python**: 3.8
# - **PyTorch**: 2.0+ with CUDA support
# - **Entry Point**: `lanistr/main_vertex_ai.py` (optimized for Vertex AI)
# - **Security**: Non-root user for production safety
#
# Let's check if you have the prerequisites and trigger the build:

# %%
# Check Cloud Build prerequisites and trigger build
import subprocess
import os

def check_command(command, name):
    """Check if a command is available"""
    try:
        result = subprocess.run([command, '--version'], 
                               capture_output=True, text=True, timeout=10)
        if result.returncode == 0:
            version = result.stdout.strip().split('\n')[0]
            print(f"✅ {name}: {version}")
            return True
        else:
            print(f"❌ {name}: Not found")
            return False
    except (subprocess.TimeoutExpired, FileNotFoundError):
        print(f"❌ {name}: Not found")
        return False

print("Checking Cloud Build prerequisites:")
print("=" * 50)

# Check gcloud
gcloud_ok = check_command('gcloud', 'Google Cloud SDK')

# Check if we're authenticated
try:
    result = subprocess.run(['gcloud', 'auth', 'list', '--filter=status:ACTIVE', '--format=value(account)'], 
                           capture_output=True, text=True, timeout=10)
    if result.returncode == 0 and result.stdout.strip():
        print(f"✅ Google Cloud Auth: {result.stdout.strip()}")
        auth_ok = True
    else:
        print("❌ Google Cloud Auth: Not authenticated")
        auth_ok = False
except:
    print("❌ Google Cloud Auth: Error checking")
    auth_ok = False

# Check if cloudbuild.yaml exists
if os.path.exists('cloudbuild.yaml'):
    print("✅ cloudbuild.yaml: Found")
    cloudbuild_ok = True
else:
    print("❌ cloudbuild.yaml: Not found")
    cloudbuild_ok = False

# Check if trigger script exists
if os.path.exists('trigger_cloud_build.sh'):
    print("✅ trigger_cloud_build.sh: Found")
    script_ok = True
else:
    print("❌ trigger_cloud_build.sh: Not found")
    script_ok = False

print("\nSummary:")
if all([gcloud_ok, auth_ok, cloudbuild_ok, script_ok]):
    print("🎉 All prerequisites are ready! You can trigger Cloud Build.")
    print(f"\nTo build the container:")
    print(f"1. Update PROJECT_ID in trigger_cloud_build.sh")
    print(f"2. Run: ./trigger_cloud_build.sh")
    print(f"\nOr manually:")
    print(f"gcloud builds submit --config=cloudbuild.yaml .")
else:
    print("⚠️  Some prerequisites are missing. Please install them first.")
    if not gcloud_ok:
        print("  - Install Google Cloud SDK: https://cloud.google.com/sdk/docs/install")
    if not auth_ok:
        print("  - Run: gcloud auth login")
    if not cloudbuild_ok:
        print("  - cloudbuild.yaml should be in the project root")
    if not script_ok:
        print("  - trigger_cloud_build.sh should be in the project root")

# Show current project
try:
    result = subprocess.run(['gcloud', 'config', 'get-value', 'project'], 
                           capture_output=True, text=True, timeout=10)
    if result.returncode == 0:
        current_project = result.stdout.strip()
        print(f"\nCurrent Google Cloud Project: {current_project}")
        if current_project != PROJECT_ID:
            print(f"⚠️  Note: Current project ({current_project}) differs from PROJECT_ID ({PROJECT_ID})")
            print(f"   You may want to run: gcloud config set project {PROJECT_ID}")
except:
    print("\nCould not determine current Google Cloud project")

print("\n" + "="*60)
print("🚀 READY TO BUILD! 🚀")
print("="*60)
print(f"\nYour container will be available at:")
print(f"gcr.io/{PROJECT_ID}/lanistr:latest")
print(f"\nAfter building, update your notebook with this container URI.")

# %%
upload_data_to_gcs('./data/mimic-iv/', 'lanistr-data/mimic-iv/')
upload_data_to_gcs('./lanistr/configs/', 'lanistr-configs/')
upload_data_to_gcs('./vertex_ai_configs/', 'vertex-ai-configs/')
# Out:
# /Users/stuartgano/lanistr/venv/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ✅ Uploaded ./data/mimic-iv/.DS_Store to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/.DS_Store
# ✅ Uploaded ./data/mimic-iv/mimic-iv.jsonl to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-iv.jsonl
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p16161191_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p16161191_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p38314794_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p38314794_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p27673588_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p27673588_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p78348834_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p78348834_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p88088261_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p88088261_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p27660454_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p27660454_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p81282050_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p81282050_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p67864269_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p67864269_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p58745169_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p58745169_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p89334762_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p89334762_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p84002230_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p84002230_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p99089066_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p99089066_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p93043441_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p93043441_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p49219557_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p49219557_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p71123579_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p71123579_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p75417270_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p75417270_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p90359802_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p90359802_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p56034746_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p56034746_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p94839060_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p94839060_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p82810012_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p82810012_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p47539077_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p47539077_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p47087548_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p47087548_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p54176596_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p54176596_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p94648484_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p94648484_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p21626401_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p21626401_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p41923237_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p41923237_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p19492494_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p19492494_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p75063343_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p75063343_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p97539171_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p97539171_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p99545583_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p99545583_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p92236867_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p92236867_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p91398888_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p91398888_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p12323656_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p12323656_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p36374669_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p36374669_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p68057635_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p68057635_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p98254593_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p98254593_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p47404541_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p47404541_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p60389431_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p60389431_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p29181871_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p29181871_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p18790463_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p18790463_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p93273002_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p93273002_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p38527252_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p38527252_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p42768346_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p42768346_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p20662215_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p20662215_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p18068142_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p18068142_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p87726845_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p87726845_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p31384065_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p31384065_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p67532959_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p67532959_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p77183698_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p77183698_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p97552560_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p97552560_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p39452312_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p39452312_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p64085179_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p64085179_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p42331272_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p42331272_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p61430073_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p61430073_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p28894288_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p28894288_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p11967400_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p11967400_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p52709417_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p52709417_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p53208738_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p53208738_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p32802153_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p32802153_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p95574530_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p95574530_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p54364385_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p54364385_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p85802513_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p85802513_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p17396797_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p17396797_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p19270371_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p19270371_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p35185834_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p35185834_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p44918940_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p44918940_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p35714868_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p35714868_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p44359222_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p44359222_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p62314579_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p62314579_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p19875446_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p19875446_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p83928504_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p83928504_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p54230674_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p54230674_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p90329180_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p90329180_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p86742014_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p86742014_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p70544619_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p70544619_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p44099610_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p44099610_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p68214908_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p68214908_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p70670742_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p70670742_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p61621403_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p61621403_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p78438848_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p78438848_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p32145843_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p32145843_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p64259752_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p64259752_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p34151157_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p34151157_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p12466189_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p12466189_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p72824236_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p72824236_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p28591459_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p28591459_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p33088276_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p33088276_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p72302540_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p72302540_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p40576943_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p40576943_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p13136042_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p13136042_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p49293633_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p49293633_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p14148174_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p14148174_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p61854633_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p61854633_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p28232105_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p28232105_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p39104806_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p39104806_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p39473507_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p39473507_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p47722154_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p47722154_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p55686461_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p55686461_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p85725289_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p85725289_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p57871562_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p57871562_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p81243450_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p81243450_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p21127044_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p21127044_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p95225924_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p95225924_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p18302867_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p18302867_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p49057731_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p49057731_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p53451314_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p53451314_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p55158093_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p55158093_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p75688500_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p75688500_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p82826687_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p82826687_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p33018539_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p33018539_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p16338012_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p16338012_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p33435010_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p33435010_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p46947148_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p46947148_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p32546685_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p32546685_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p96775374_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p96775374_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p70241073_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p70241073_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p17606683_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p17606683_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p17626744_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p17626744_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p49761825_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p49761825_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p37103558_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p37103558_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p38003745_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p38003745_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p55062292_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p55062292_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p66278858_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p66278858_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p48208895_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p48208895_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p53631487_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p53631487_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p46236852_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p46236852_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p33559599_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p33559599_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p73994562_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p73994562_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p73616789_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p73616789_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p27936215_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p27936215_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p51468820_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p51468820_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p75401197_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p75401197_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p97868063_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p97868063_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p32737468_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p32737468_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p95732988_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p95732988_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p39702293_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p39702293_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p60072048_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p60072048_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p35291936_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p35291936_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p67899835_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p67899835_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p21575293_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p21575293_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p83933918_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p83933918_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p19108348_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p19108348_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p19200629_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p19200629_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p99499424_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p99499424_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p84900640_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p84900640_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p80042333_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p80042333_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p83077456_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p83077456_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p85904555_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p85904555_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p97369968_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p97369968_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p20717113_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p20717113_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p39789751_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p39789751_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p28095771_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p28095771_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p13786758_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p13786758_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p99138590_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p99138590_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p91948496_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p91948496_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p13640725_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p13640725_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p33290126_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p33290126_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p88305303_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p88305303_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p89894863_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p89894863_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p23534404_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p23534404_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p13409875_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p13409875_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p96059945_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p96059945_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p27993941_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p27993941_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p46533683_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p46533683_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p55843304_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p55843304_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p67067821_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p67067821_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p13465125_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p13465125_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p86107399_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p86107399_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p23363485_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p23363485_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p60600245_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p60600245_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p74489193_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p74489193_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p99880553_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p99880553_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p34419311_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p34419311_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p58721539_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p58721539_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p59578710_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p59578710_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p31028941_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p31028941_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p20656462_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p20656462_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p24006907_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p24006907_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p92965180_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p92965180_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p72046220_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p72046220_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p92802796_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p92802796_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p74168706_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p74168706_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p18984432_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p18984432_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p17002002_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p17002002_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p15825808_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p15825808_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p80446610_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p80446610_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p72840237_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p72840237_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p74796555_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p74796555_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p48590294_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p48590294_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p59709010_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p59709010_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p93820425_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p93820425_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p50631115_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p50631115_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p30035402_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p30035402_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p33711293_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p33711293_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p17318633_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p17318633_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p14637472_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p14637472_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p19694022_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p19694022_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p41437764_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p41437764_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p31844593_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p31844593_vitals.csv
# ✅ Uploaded ./data/mimic-iv/timeseries/patient_p87212130_vitals.csv to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/timeseries/patient_p87212130_vitals.csv
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p40576943/s69561873/00cb9b51.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p40576943/s69561873/00cb9b51.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p46947148/s79172166/02761f81.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p46947148/s79172166/02761f81.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47087548/s95103236/00f3b63b.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47087548/s95103236/00f3b63b.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p42768346/s68748743/014a61d8.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p42768346/s68748743/014a61d8.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p48208895/s98634392/0497d186.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p48208895/s98634392/0497d186.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p41923237/s96478564/02fb58b1.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p41923237/s96478564/02fb58b1.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p46533683/s87141551/05be6b95.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p46533683/s87141551/05be6b95.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p48590294/s80637118/05de5e1b.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p48590294/s80637118/05de5e1b.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p42331272/s97382022/00ef3437.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p42331272/s97382022/00ef3437.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p44359222/s99467477/02febe27.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p44359222/s99467477/02febe27.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p46236852/s53898054/054a623f.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p46236852/s53898054/054a623f.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49219557/s96031168/00d9ed81.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49219557/s96031168/00d9ed81.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47404541/s51880295/01e8ce3c.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47404541/s51880295/01e8ce3c.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49293633/s99333321/00f2c3fa.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49293633/s99333321/00f2c3fa.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p41437764/s70623371/052df5e5.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p41437764/s70623371/052df5e5.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49761825/s59013376/0337322d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49761825/s59013376/0337322d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47722154/s85171786/05e95957.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47722154/s85171786/05e95957.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47539077/s54393745/04461dbb.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p47539077/s54393745/04461dbb.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49057731/s63303132/05b6aa6f.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p49057731/s63303132/05b6aa6f.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p44099610/s79037020/043edfc8.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p44099610/s79037020/043edfc8.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p44918940/s80334034/00bb8e8d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p4/p44918940/s80334034/00bb8e8d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p38527252/s94942171/0289b48c.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p38527252/s94942171/0289b48c.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33018539/s50328835/02125745.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33018539/s50328835/02125745.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p35291936/s61385657/01290f8b.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p35291936/s61385657/01290f8b.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39473507/s69730634/05d4bb5f.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39473507/s69730634/05d4bb5f.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33435010/s92420678/010663d1.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33435010/s92420678/010663d1.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p35714868/s73272062/026e1dee.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p35714868/s73272062/026e1dee.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32737468/s60337737/00ddf5a3.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32737468/s60337737/00ddf5a3.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33711293/s76587943/00fc9bca.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33711293/s76587943/00fc9bca.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39702293/s75038289/041cde1a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39702293/s75038289/041cde1a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39104806/s84054295/05e0003d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39104806/s84054295/05e0003d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39789751/s89271659/01daed5b.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39789751/s89271659/01daed5b.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32145843/s52951806/039859f5.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32145843/s52951806/039859f5.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p34151157/s57842759/03fb3871.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p34151157/s57842759/03fb3871.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33290126/s81599022/00bc9df4.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33290126/s81599022/00bc9df4.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p31384065/s66673734/00d95111.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p31384065/s66673734/00d95111.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p38003745/s58555271/01f7f53a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p38003745/s58555271/01f7f53a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32802153/s88338369/04042ea5.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32802153/s88338369/04042ea5.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33559599/s67657129/02c93e79.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33559599/s67657129/02c93e79.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p31844593/s50298425/011e2ae0.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p31844593/s50298425/011e2ae0.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p30035402/s69496794/00a25194.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p30035402/s69496794/00a25194.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p35185834/s76976261/03e9e887.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p35185834/s76976261/03e9e887.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32546685/s98166499/035192ee.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p32546685/s98166499/035192ee.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p34419311/s88012422/0174c3b8.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p34419311/s88012422/0174c3b8.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39452312/s55561746/0291d4be.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p39452312/s55561746/0291d4be.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p31028941/s83545045/020c9305.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p31028941/s83545045/020c9305.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33088276/s72726025/0229688e.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p33088276/s72726025/0229688e.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p36374669/s54105768/0479057e.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p36374669/s54105768/0479057e.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p38314794/s54276584/02b1b4c3.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p38314794/s54276584/02b1b4c3.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p37103558/s87370283/0355ef0a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p3/p37103558/s87370283/0355ef0a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p28232105/s73910967/014ec479.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p28232105/s73910967/014ec479.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p29181871/s97421129/032d2226.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p29181871/s97421129/032d2226.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p20656462/s64771542/04e90f98.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p20656462/s64771542/04e90f98.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p24006907/s50579929/0513a14f.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p24006907/s50579929/0513a14f.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p27993941/s74358476/056d044a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p27993941/s74358476/056d044a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p27673588/s58521362/04f0f4e9.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p27673588/s58521362/04f0f4e9.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p21626401/s95099803/0150e49a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p21626401/s95099803/0150e49a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p21575293/s57793464/013b0c39.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p21575293/s57793464/013b0c39.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p28894288/s79051616/012660f8.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p28894288/s79051616/012660f8.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p27936215/s54234973/0430810c.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p27936215/s54234973/0430810c.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p28095771/s51095367/03fb8b47.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p2/p28095771/s51095367/03fb8b47.jpg
# ...
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p88305303/s51373110/02504302.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p88305303/s51373110/02504302.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p82810012/s67558738/05d772aa.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p82810012/s67558738/05d772aa.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p85802513/s59818689/03d0a2c8.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p85802513/s59818689/03d0a2c8.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p88088261/s74671551/02e9c9fa.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p88088261/s74671551/02e9c9fa.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p86107399/s58280112/0115a369.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p86107399/s58280112/0115a369.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p87212130/s86120086/03e7261e.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p87212130/s86120086/03e7261e.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p87726845/s91607771/05c9d8d0.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p87726845/s91607771/05c9d8d0.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p83933918/s97915369/03cb1e29.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p83933918/s97915369/03cb1e29.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p85725289/s89881779/021c9d3f.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p85725289/s89881779/021c9d3f.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p89894863/s69989327/03be66cd.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p89894863/s69989327/03be66cd.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p84002230/s79739214/05d2d26b.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p84002230/s79739214/05d2d26b.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p84900640/s73223917/016118ba.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p84900640/s73223917/016118ba.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p83077456/s76922675/042c24a6.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p83077456/s76922675/042c24a6.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p85904555/s76838187/03320bbe.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p85904555/s76838187/03320bbe.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p81282050/s89499121/035d29fa.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p81282050/s89499121/035d29fa.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p80446610/s59239459/0554ce3d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p80446610/s59239459/0554ce3d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p89334762/s68688833/04da1aa9.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p89334762/s68688833/04da1aa9.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p80042333/s55193845/05d55314.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p80042333/s55193845/05d55314.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p82826687/s79535892/0226ce94.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p82826687/s79535892/0226ce94.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p83928504/s96296887/04f3c5ae.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p8/p83928504/s96296887/04f3c5ae.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p61854633/s60993267/00b9daf0.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p61854633/s60993267/00b9daf0.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67532959/s50352086/04a8c8c1.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67532959/s50352086/04a8c8c1.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67067821/s87934976/016800d7.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67067821/s87934976/016800d7.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67864269/s58091024/054f739a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67864269/s58091024/054f739a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p61621403/s63182376/057c077a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p61621403/s63182376/057c077a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p60389431/s84352203/012254f3.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p60389431/s84352203/012254f3.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p60072048/s82833197/03a50a5a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p60072048/s82833197/03a50a5a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67899835/s67037004/0105961e.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p67899835/s67037004/0105961e.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p64085179/s72637950/016a1509.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p64085179/s72637950/016a1509.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p68214908/s70935600/0162319e.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p68214908/s70935600/0162319e.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p62314579/s92531346/04f8d067.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p62314579/s92531346/04f8d067.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p66278858/s75798038/05bdf65d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p66278858/s75798038/05bdf65d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p64259752/s89287272/04160b36.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p64259752/s89287272/04160b36.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p60600245/s50679872/017c1e73.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p60600245/s50679872/017c1e73.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p61430073/s84928128/045de982.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p61430073/s84928128/045de982.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p68057635/s69957568/04961d6e.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p6/p68057635/s69957568/04961d6e.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p11967400/s82792177/01e16c63.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p11967400/s82792177/01e16c63.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19200629/s78289285/02844105.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19200629/s78289285/02844105.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18984432/s52685019/0248fdb4.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18984432/s52685019/0248fdb4.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p16338012/s96257168/00d7c7ef.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p16338012/s96257168/00d7c7ef.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17002002/s68418430/03bcff82.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17002002/s68418430/03bcff82.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13640725/s59646752/01265036.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13640725/s59646752/01265036.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13409875/s74079884/0222e9cd.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13409875/s74079884/0222e9cd.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p12323656/s54335246/04f5477a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p12323656/s54335246/04f5477a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17318633/s55122934/00e04f12.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17318633/s55122934/00e04f12.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17606683/s92927386/049bf688.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17606683/s92927386/049bf688.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19108348/s73628581/0133eb12.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19108348/s73628581/0133eb12.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18790463/s89632955/049a705a.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18790463/s89632955/049a705a.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13465125/s62040288/0592607c.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13465125/s62040288/0592607c.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19694022/s91844668/04b4a72d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19694022/s91844668/04b4a72d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p14637472/s61830477/03a57667.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p14637472/s61830477/03a57667.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19875446/s82850163/047a99f6.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19875446/s82850163/047a99f6.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19270371/s99635213/01e79430.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19270371/s99635213/01e79430.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13136042/s73472464/0214c400.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13136042/s73472464/0214c400.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p12466189/s65701112/04fcac1d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p12466189/s65701112/04fcac1d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p15825808/s55631633/01e52a88.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p15825808/s55631633/01e52a88.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18068142/s75899044/01a4332d.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18068142/s75899044/01a4332d.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17626744/s86899336/0337800f.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17626744/s86899336/0337800f.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p14148174/s77541016/01be8d37.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p14148174/s77541016/01be8d37.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19492494/s95728292/03fa7fe7.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p19492494/s95728292/03fa7fe7.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13786758/s80383951/03cc4f36.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p13786758/s80383951/03cc4f36.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18302867/s68337538/058aea98.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p18302867/s68337538/058aea98.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17396797/s83442680/028a57ce.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p17396797/s83442680/028a57ce.jpg
# ✅ Uploaded ./data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p16161191/s77433240/04fa3238.jpg to gs://lanistr-mgm-digitalconcierge-data/lanistr-data/mimic-iv/mimic-cxr-jpg/2.0.0/files/p1/p16161191/s77433240/04fa3238.jpg
# /Users/stuartgano/lanistr/venv/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ✅ Uploaded ./lanistr/configs/mimic-iv_pretrain_local.yaml to gs://lanistr-mgm-digitalconcierge-data/lanistr-configs/mimic-iv_pretrain_local.yaml
# ✅ Uploaded ./lanistr/configs/amazon_finetune_beauty.yaml to gs://lanistr-mgm-digitalconcierge-data/lanistr-configs/amazon_finetune_beauty.yaml
# ✅ Uploaded ./lanistr/configs/mimic_finetune.yaml to gs://lanistr-mgm-digitalconcierge-data/lanistr-configs/mimic_finetune.yaml
# ✅ Uploaded ./lanistr/configs/amazon_pretrain_office.yaml to gs://lanistr-mgm-digitalconcierge-data/lanistr-configs/amazon_pretrain_office.yaml
# ✅ Uploaded ./lanistr/configs/mimic_pretrain.yaml to gs://lanistr-mgm-digitalconcierge-data/lanistr-configs/mimic_pretrain.yaml
# ✅ Uploaded ./lanistr/configs/amazon_finetune_fashion.yaml to gs://lanistr-mgm-digitalconcierge-data/lanistr-configs/amazon_finetune_fashion.yaml
# /Users/stuartgano/lanistr/venv/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ✅ Uploaded ./vertex_ai_configs/mimic_finetune_vertex.yaml to gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/mimic_finetune_vertex.yaml
# ✅ Uploaded ./vertex_ai_configs/mimic_pretrain_vertex.yaml to gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/mimic_pretrain_vertex.yaml
# ✅ Uploaded ./vertex_ai_configs/amazon_pretrain_vertex.yaml to gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/amazon_pretrain_vertex.yaml
# 'gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/'

# %%
! gcloud auth application-default login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=16mbYEIYB3H9qKlQ8XHzMjE15E0hTO&access_type=offline&code_challenge=GekRtzysKR1IQAEyLioOueacRj3GMjBJBr-q2KJykfY&code_challenge_method=S256
#
#
# Credentials saved to file: [/Users/stuartgano/.config/gcloud/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
# WARNING:
# Cannot add the project "831221572395" to ADC as the quota project because the account in ADC does not have the "serviceusage.services.use" permission on this project. You might receive a "quota_exceeded" or "API not enabled" error. Run $ gcloud auth application-default set-quota-project to add a quota project.
#
#
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
#   $ gcloud components update
#
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey

# %%
! gcloud auth application-default set-quota-project mgm-digitalconcierge
# Out:
# Credentials saved to file: [/Users/stuartgano/.config/gcloud/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
#
# Quota project "mgm-digitalconcierge" was added to ADC which can be used by Google client libraries for billing and quota. Note that some services may still bill the project owning the resource.

# %% [markdown]
# ## Creating Vertex AI Training Jobs
#
# Now let's create actual training job configurations using your project's Vertex AI configs.

# %%
# Function to create Vertex AI custom job
def create_vertex_ai_job(
    job_name,
    config_file,
    machine_type="n1-standard-8",
    accelerator_type="NVIDIA_TESLA_V100",
    accelerator_count=1
):
    """Create a Vertex AI custom training job using actual project configs"""
    
    # Container image for LANISTR (you'll need to build this)
    container_uri = f"gcr.io/mgm-digitalconcierge/lanistr:latest"
    
    # Job configuration
    job_config = {
        "display_name": job_name,
        "job_spec": {
            "worker_pool_specs": [
                {
                    "machine_spec": {
                        "machine_type": machine_type,
                        "accelerator_type": accelerator_type,
                        "accelerator_count": accelerator_count
                    },
                    "replica_count": 1,
                    "container_spec": {
                        "image_uri": container_uri,
                        "args": [
                            "python", "lanistr/main.py",
                            "--config", config_file
                        ]
                    }
                }
            ]
        }
    }
    
    return job_config

# Actual job configurations from your project
print("Available Training Jobs:")

# MIMIC-IV Pre-training
mimic_pretrain_config = create_vertex_ai_job(
    job_name="mimic-pretrain-001",
    config_file=f"gs://{BUCKET_NAME}/vertex-ai-configs/mimic_pretrain_vertex.yaml",
    machine_type="n1-standard-8",
    accelerator_type="NVIDIA_TESLA_V100",
    accelerator_count=1
)
print("\n1. MIMIC-IV Pre-training:")
print(json.dumps(mimic_pretrain_config, indent=2))

# MIMIC-IV Fine-tuning
mimic_finetune_config = create_vertex_ai_job(
    job_name="mimic-finetune-001",
    config_file=f"gs://{BUCKET_NAME}/vertex-ai-configs/mimic_finetune_vertex.yaml",
    machine_type="n1-standard-4",
    accelerator_type="NVIDIA_TESLA_T4",
    accelerator_count=1
)
print("\n2. MIMIC-IV Fine-tuning:")
print(json.dumps(mimic_finetune_config, indent=2))

# Amazon Pre-training
amazon_pretrain_config = create_vertex_ai_job(
    job_name="amazon-pretrain-001",
    config_file=f"gs://{BUCKET_NAME}/vertex-ai-configs/amazon_pretrain_vertex.yaml",
    machine_type="n1-standard-4",
    accelerator_type="NVIDIA_TESLA_T4",
    accelerator_count=1
)
print("\n3. Amazon Pre-training:")
print(json.dumps(amazon_pretrain_config, indent=2))

mimic_pretrain_config = create_vertex_ai_job(
    job_name="mimic-pretrain-001",
    config_file=f"gs://{BUCKET_NAME}/vertex-ai-configs/mimic_pretrain_vertex.yaml",
    machine_type="n1-standard-8",
    accelerator_type="NVIDIA_TESLA_V100",
    accelerator_count=1
)
mimic_finetune_config = create_vertex_ai_job(
    job_name="mimic-finetune-001",
    config_file=f"gs://{BUCKET_NAME}/vertex-ai-configs/mimic_finetune_vertex.yaml",
    machine_type="n1-standard-4",
    accelerator_type="NVIDIA_TESLA_T4",
    accelerator_count=1
)
# Out:
# Available Training Jobs:
#
# 1. MIMIC-IV Pre-training:
# {
#   "display_name": "mimic-pretrain-001",
#   "job_spec": {
#     "worker_pool_specs": [
#       {
#         "machine_spec": {
#           "machine_type": "n1-standard-8",
#           "accelerator_type": "NVIDIA_TESLA_V100",
#           "accelerator_count": 1
#         },
#         "replica_count": 1,
#         "container_spec": {
#           "image_uri": "gcr.io/mgm-digitalconcierge/lanistr:latest",
#           "args": [
#             "python",
#             "lanistr/main.py",
#             "--config",
#             "gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/mimic_pretrain_vertex.yaml"
#           ]
#         }
#       }
#     ]
#   }
# }
#
# 2. MIMIC-IV Fine-tuning:
# {
#   "display_name": "mimic-finetune-001",
#   "job_spec": {
#     "worker_pool_specs": [
#       {
#         "machine_spec": {
#           "machine_type": "n1-standard-4",
#           "accelerator_type": "NVIDIA_TESLA_T4",
#           "accelerator_count": 1
#         },
#         "replica_count": 1,
#         "container_spec": {
#           "image_uri": "gcr.io/mgm-digitalconcierge/lanistr:latest",
#           "args": [
#             "python",
#             "lanistr/main.py",
#             "--config",
#             "gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/mimic_finetune_vertex.yaml"
#           ]
#         }
#       }
#     ]
#   }
# }
#
# 3. Amazon Pre-training:
# {
#   "display_name": "amazon-pretrain-001",
#   "job_spec": {
#     "worker_pool_specs": [
#       {
#         "machine_spec": {
#           "machine_type": "n1-standard-4",
#           "accelerator_type": "NVIDIA_TESLA_T4",
#           "accelerator_count": 1
#         },
#         "replica_count": 1,
#         "container_spec": {
#           "image_uri": "gcr.io/mgm-digitalconcierge/lanistr:latest",
#           "args": [
#             "python",
#             "lanistr/main.py",
#             "--config",
#             "gs://lanistr-mgm-digitalconcierge-data/vertex-ai-configs/amazon_pretrain_vertex.yaml"
#           ]
#         }
#       }
#     ]
#   }
# }

# %%
! ./trigger_cloud_build.sh
# Out:
# 🚀 LANISTR Cloud Build Trigger Script
# ==============================================
#
# Configuration:
#   Project ID: mgm-digitalconcierge
#   Region: us-central1
#
# 📋 Step 1: Checking prerequisites...
# ✅ Google Cloud SDK is installed
# ✅ Authenticated with Google Cloud
# ⚠️  Setting project to mgm-digitalconcierge
# Reauthentication required.
# Please enter your password:

# %% [markdown]
# ## Submitting Training Jobs
#
# Now let's submit the actual training jobs to Vertex AI.

# %%
# Function to submit training jobs
def submit_training_job(job_config):
    """Submit a training job to Vertex AI"""
    try:
        # Create the custom job
        job = aiplatform.CustomJob(
            display_name=job_config["display_name"],
            worker_pool_specs=job_config["job_spec"]["worker_pool_specs"],
            project=PROJECT_ID,
            location='us-central1',
            staging_bucket=f'gs://{BUCKET_NAME}'

        )
        
        # Submit the job
        job.run()
        
        print(f"✅ Successfully submitted job: {job_config['display_name']}")
        print(f"Job ID: {job.name}")
        print(f"Job URL: https://console.cloud.google.com/vertex-ai/training/custom-jobs/{job.name}")
        
        return job
        
    except Exception as e:
        print(f"❌ Failed to submit job: {e}")
        return None

# Submit actual jobs
print("Submitting Training Jobs:")
print("\nNote: Uncomment the lines below to actually submit jobs")

# # Submit MIMIC-IV pre-training job
mimic_pretrain_job = submit_training_job(mimic_pretrain_config)
# 
# # Submit MIMIC-IV fine-tuning job
# mimic_finetune_job = submit_training_job(mimic_finetune_config)
# 
# # Submit Amazon pre-training job
# amazon_pretrain_job = submit_training_job(amazon_pretrain_config)

print("\nTo submit jobs manually:")
print("1. Update PROJECT_ID, REGION, and BUCKET_NAME above")
print("2. Upload your data and configs to GCS")
print("3. Build and push your LANISTR container")
print("4. Uncomment the job submission lines above")
print("5. Run the cell")
# Out:
# Submitting Training Jobs:
#
# Note: Uncomment the lines below to actually submit jobs
# Creating CustomJob
# CustomJob created. Resource name: projects/419850945193/locations/us-central1/customJobs/2698590297822068736
# To use this CustomJob in another session:
# custom_job = aiplatform.CustomJob.get('projects/419850945193/locations/us-central1/customJobs/2698590297822068736')
# View Custom Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/2698590297822068736?project=419850945193
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 2
# CustomJob projects/419850945193/locations/us-central1/customJobs/2698590297822068736 current state:
# 5
# ❌ Failed to submit job: Job failed with:
# code: 3
# message: "The replica workerpool0-0 exited with a non-zero status of 1. Termination reason: Error. To find out more about why your job exited please check the logs: https://console.cloud.google.com/logs/viewer?project=419850945193&resource=ml_job%2Fjob_id%2F2698590297822068736&advancedFilter=resource.type%3D%22ml_job%22%0Aresource.labels.job_id%3D%222698590297822068736%22"
#
#
# To submit jobs manually:
# 1. Update PROJECT_ID, REGION, and BUCKET_NAME above
# 2. Upload your data and configs to GCS
# 3. Build and push your LANISTR container
# 4. Uncomment the job submission lines above
# 5. Run the cell

# %% [markdown]
# ## Complete Workflow Example
#
# Let's put everything together in a complete workflow using your actual project structure.

# %%
# Complete workflow function
def run_complete_workflow(
    dataset_name,
    task_type,
    job_name=None
):
    """Run a complete LANISTR training workflow on Vertex AI"""
    
    if job_name is None:
        timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
        job_name = f"{dataset_name}-{task_type}-{timestamp}"
    
    print(f"🚀 Starting LANISTR {task_type} workflow for {dataset_name}")
    print(f"Job name: {job_name}")
    print("-" * 60)
    
    # Step 1: Upload data
    print("📤 Step 1: Uploading data...")
    if dataset_name == 'mimic-iv':
        data_gcs_path = upload_data_to_gcs('./data/mimic-iv/', 'lanistr-data/mimic-iv/')
    else:
        print(f"❌ Dataset {dataset_name} not supported yet")
        return None
    
    # Step 2: Upload configurations
    print("📤 Step 2: Uploading configurations...")
    config_gcs_path = upload_data_to_gcs('./vertex_ai_configs/', 'vertex-ai-configs/')
    
    # Step 3: Create job configuration
    print("⚙️  Step 3: Creating job configuration...")
    config_file = f"gs://{BUCKET_NAME}/vertex-ai-configs/{dataset_name}_{task_type}_vertex.yaml"
    job_config = create_vertex_ai_job(
        job_name=job_name,
        config_file=config_file
    )
    
    # Step 4: Submit job
    print("🚀 Step 4: Submitting training job...")
    job = submit_training_job(job_config)
    
    if job:
        print("\n✅ Workflow completed successfully!")
        print(f"Monitor your job at: https://console.cloud.google.com/vertex-ai/training/custom-jobs/{job.name}")
        return job
    else:
        print("\n❌ Workflow failed!")
        return None

# Example workflow calls
print("Complete Workflow Examples:")
print("\n1. MIMIC-IV Pre-training:")
print("run_complete_workflow('mimic-iv', 'pretrain')")

print("\n2. MIMIC-IV Fine-tuning:")
print("run_complete_workflow('mimic-iv', 'finetune')")

print("\nTo run a workflow:")
print("1. Update PROJECT_ID, REGION, and BUCKET_NAME above")
print("2. Build and push your LANISTR container to GCR")
print("3. Uncomment and run the workflow calls above")

# %% [markdown]
# ## Next Steps
#
# Now that you understand how to deploy LANISTR to the cloud, here are your next steps:
#
# 1. **Set up Google Cloud**: Complete the authentication and project setup
# 2. **Build LANISTR container**: Create a Docker container with LANISTR and push to GCR
# 3. **Upload your data**: Use the upload functions to get your data to GCS
# 4. **Submit training jobs**: Use the provided functions to start training
# 5. **Monitor and optimize**: Track job progress and optimize for cost/performance
# 6. **Download results**: Retrieve your trained models and logs
#
# ## Summary
#
# This tutorial has shown you how to:
#
# - Set up Google Cloud authentication and configuration
# - Upload data and configurations to Google Cloud Storage
# - Create and submit custom training jobs to Vertex AI using your actual project configs
# - Monitor job progress and download results
# - Optimize costs and troubleshoot common issues
#
# LANISTR provides a powerful framework for multimodal learning that can be easily deployed to the cloud, allowing you to focus on your research and development without worrying about local hardware constraints.
#
# Happy cloud training! ☁️🚀
